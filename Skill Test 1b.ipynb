# %% [markdown]
# <a href="https://colab.research.google.com/github/NitishChander/PPML/blob/main/Skill%20Test%201b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1B
import numpy as np
A = np.array([[2, 3],
              [1, 2]])

b = np.array([5, 3])

x = np.linalg.solve(A, b)

print("Solution vector x:")
print(x)
# Out:
# Solution vector x:
# [1. 1.]
