# %% [markdown]
# <a href="https://colab.research.google.com/github/NitishChander/PPML/blob/main/Skill%20Test%201a.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1A
scores = [78, 45, 90, 67, 52, 33, 81, 49, 60, 74, 88, 41, 55, 69, 72, 95, 38, 50, 64, 84]

average_score = sum(scores) / len(scores)
highest_score = max(scores)
lowest_score = min(scores)

print("Average Score:", average_score)
print("Highest Score:", highest_score)
print("Lowest Score:", lowest_score)

print("\nPass/Fail Status:")
for i, score in enumerate(scores, start=1):
    if score >= 50:
        print("Student", i, ":", score, "- Pass")
    else:
        print("Student", i, ":", score, "- Fail")

print("\nStudent Grades:")
for i, score in enumerate(scores, start=1):
    if score >= 85:
        grade = "A"
    elif score >= 70:
        grade = "B"
    elif score >= 60:
        grade = "C"
    elif score >= 50:
        grade = "D"
    else:
        grade = "F"

    print("Student", i, ":", score, "- Grade", grade)
# Out:
# Average Score: 64.25
# Highest Score: 95
# Lowest Score: 33
#
# Pass/Fail Status:
# Student 1 : 78 - Pass
# Student 2 : 45 - Fail
# Student 3 : 90 - Pass
# Student 4 : 67 - Pass
# Student 5 : 52 - Pass
# Student 6 : 33 - Fail
# Student 7 : 81 - Pass
# Student 8 : 49 - Fail
# Student 9 : 60 - Pass
# Student 10 : 74 - Pass
# Student 11 : 88 - Pass
# Student 12 : 41 - Fail
# Student 13 : 55 - Pass
# Student 14 : 69 - Pass
# Student 15 : 72 - Pass
# Student 16 : 95 - Pass
# Student 17 : 38 - Fail
# Student 18 : 50 - Pass
# Student 19 : 64 - Pass
# Student 20 : 84 - Pass
#
# Student Grades:
# Student 1 : 78 - Grade B
# Student 2 : 45 - Grade F
# Student 3 : 90 - Grade A
# Student 4 : 67 - Grade C
# Student 5 : 52 - Grade D
# Student 6 : 33 - Grade F
# Student 7 : 81 - Grade B
# Student 8 : 49 - Grade F
# Student 9 : 60 - Grade C
# Student 10 : 74 - Grade B
# Student 11 : 88 - Grade A
# Student 12 : 41 - Grade F
# Student 13 : 55 - Grade D
# Student 14 : 69 - Grade C
# ...
