# %% [markdown]
# <a href="https://colab.research.google.com/github/NitishChander/PPML/blob/main/240901069%20Data%20Visualization%204.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import plotly.express as px

# seaborn style
sns.set()

# Correct data (same length)
Xpoints = np.array([0, 20, 120, 200, 250, 300, 350])
Ypoints = np.array([10, 80, 100, 120, 150, 180, 250])

# Matplotlib + Seaborn Line Plot
plt.figure(figsize=(8,5))
plt.plot(Xpoints, Ypoints, marker='o')
plt.title("Sample Line Plot")
plt.xlabel("X Points")
plt.ylabel("Y Points")
plt.grid(True)
plt.show()

# Plotly Interactive Plot
df = pd.DataFrame({"X": Xpoints, "Y": Ypoints})
fig = px.line(df, x="X", y="Y", markers=True, title="Interactive Plot")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
sns.scatterplot(data=df, x='X', y='Y')
plt.show()

# %%
sns.barplot(data=df, x='X', y='Y')
plt.show()

# %%
#3-D plot
X=np.array([1,2,6,8,12,14,20])
Y=np.array([3,8,1,10,12,16,18])
Fig=plt.figure(figsize=(12,8))
Ax=plt.axes(projection='3d')
Plt_3d=Ax.scatter3D(X,Y)
# plt.colorbar(Plt_3d) # This line is usually used with a 'c' argument in scatter3D to represent color data.
plt.show()
#plotly package
X_plotly=np.array([10,80,100,120,150,180,250])
df_plotly = pd.DataFrame({"X": X_plotly}) # Create a DataFrame for plotly
fig=px.scatter(df_plotly, x="X")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
