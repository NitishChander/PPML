# %% [markdown]
# <a href="https://colab.research.google.com/github/NitishChander/PPML/blob/main/Data%20Aggregation%20and%20Grouping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame({
    'A': ['sai', 'sai', 'subu', 'yuvi', 'rithi', 'subu'],
    'B': ['one', 'one', 'three', 'one', 'three', 'three'],
    'C': np.random.randint(5, size=6),
    'D': np.random.randint(5, size=6),
    'E': np.random.randint(5, size=6)
})

print("\nOriginal DataFrame\n", df)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    sai    one  4  0  4
# 1    sai    one  3  3  3
# 2   subu  three  4  2  4
# 3   yuvi    one  0  4  4
# 4  rithi  three  4  3  4
# 5   subu  three  3  0  2

# %%
df1 = df.groupby(['A', 'B'], as_index=False)['C'].sum()
print("\nOriginal DataFrame\n", df)
print("\nGroup by (multi-column): with one column sum\n", df1)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    sai    one  4  0  4
# 1    sai    one  3  3  3
# 2   subu  three  4  2  4
# 3   yuvi    one  0  4  4
# 4  rithi  three  4  3  4
# 5   subu  three  3  0  2
#
# Group by (multi-column): with one column sum
#         A      B  C
# 0  rithi  three  4
# 1    sai    one  7
# 2   subu  three  7
# 3   yuvi    one  0

# %%
df2 = df.groupby(['A', 'B'], as_index=False).sum()
print("\nOriginal DataFrame\n", df)
print("\nGroup by (multi-column): with multi columns sum\n", df2)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    sai    one  4  0  4
# 1    sai    one  3  3  3
# 2   subu  three  4  2  4
# 3   yuvi    one  0  4  4
# 4  rithi  three  4  3  4
# 5   subu  three  3  0  2
#
# Group by (multi-column): with multi columns sum
#         A      B  C  D  E
# 0  rithi  three  4  3  4
# 1    sai    one  7  3  7
# 2   subu  three  7  2  6
# 3   yuvi    one  0  4  4

# %%
df3 = df.groupby(['A', 'B'], as_index=False)['C'].agg('sum')
print("\nOriginal DataFrame\n", df)
print("\nCombined Groupby and Aggregate function\n", df3)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    sai    one  4  0  4
# 1    sai    one  3  3  3
# 2   subu  three  4  2  4
# 3   yuvi    one  0  4  4
# 4  rithi  three  4  3  4
# 5   subu  three  3  0  2
#
# Combined Groupby and Aggregate function
#         A      B  C
# 0  rithi  three  4
# 1    sai    one  7
# 2   subu  three  7
# 3   yuvi    one  0

# %%
df4 = (
    df.groupby(['A', 'B'])
      .agg([('average', 'mean'), ('total', 'sum')])
)
print("\nOriginal DataFrame\n", df)
print("\nCombined Groupby and Aggregate function - separate column headings\n", df4)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    sai    one  4  0  4
# 1    sai    one  3  3  3
# 2   subu  three  4  2  4
# 3   yuvi    one  0  4  4
# 4  rithi  three  4  3  4
# 5   subu  three  3  0  2
#
# Combined Groupby and Aggregate function - separate column headings
#                    C             D             E
#             average total average total average total
# A     B
# rithi three     4.0     4     3.0     3     4.0     4
# sai   one       3.5     7     1.5     3     3.5     7
# subu  three     3.5     7     1.0     2     3.0     6
# yuvi  one       0.0     0     4.0     4     4.0     4

# %%
df5 = df.groupby(['A', 'B'], as_index=False).sum()
df6 = df.groupby(['A', 'B']).agg(['sum'])
print("\nOriginal DataFrame\n", df)
print("\nGroupby-sum function\n", df5)
print("\nGroupby and Aggregate - sum function\n", df6)
# Out:
# Original DataFrame
#         A      B  C  D  E
# 0    sai    one  4  0  4
# 1    sai    one  3  3  3
# 2   subu  three  4  2  4
# 3   yuvi    one  0  4  4
# 4  rithi  three  4  3  4
# 5   subu  three  3  0  2
#
# Groupby-sum function
#         A      B  C  D  E
# 0  rithi  three  4  3  4
# 1    sai    one  7  3  7
# 2   subu  three  7  2  6
# 3   yuvi    one  0  4  4
#
# Groupby and Aggregate - sum function
#                C   D   E
#             sum sum sum
# A     B
# rithi three   4   3   4
# sai   one     7   3   7
# subu  three   7   2   6
# yuvi  one     0   4   4
