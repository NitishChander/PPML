# %% [markdown]
# <a href="https://colab.research.google.com/github/NitishChander/PPML/blob/main/Data%20cleaning%20and%20preparation-%20DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe with NaN\n",df)
print("\n")
print("Dropped DataFrame\n",df.dropna())
print("\n")
# Out:
# Original Dataframe with NaN
#          one       two     three
# a -0.567348 -1.622945 -0.901463
# b       NaN       NaN       NaN
# c -1.986294 -0.332344 -0.255024
# d  1.025701 -1.610965 -0.882975
# e       NaN       NaN       NaN
# f -0.243388  0.082744 -0.103289
#
#
# Dropped DataFrame
#          one       two     three
# a -0.567348 -1.622945 -0.901463
# c -1.986294 -0.332344 -0.255024
# d  1.025701 -1.610965 -0.882975
# f -0.243388  0.082744 -0.103289

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c'])
print("Original Dataframe:\n",df)
print("\n")
print("NaN replaced with '0':\n")
print(df.fillna(0))
# Out:
# Original Dataframe:
#          one       two     three
# a  0.356796 -0.745186 -0.257830
# b       NaN       NaN       NaN
# c -0.474577  0.165660  0.643556
#
#
# NaN replaced with '0':
#
#         one       two     three
# a  0.356796 -0.745186 -0.257830
# b  0.000000  0.000000  0.000000
# c -0.474577  0.165660  0.643556

# %%
df=pd.DataFrame({'one':[10,20,80,40,50],
'two':[60,70,80,0,10]})
print("Original Dataframe:\n",df)
print("\n DataFrame with replaced values:\n")
print(df.replace({10:5,80:3}))
# Out:
# Original Dataframe:
#     one  two
# 0   10   60
# 1   20   70
# 2   80   80
# 3   40    0
# 4   50   10
#
#  DataFrame with replaced values:
#
#    one  two
# 0    5   60
# 1   20   70
# 2    3    3
# 3   40    0
# 4   50    5

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNan-with True fill:\n")
print(df['one'].isnull())
# Out:
# Original Dataframe:
#          one       two     three
# a  0.778335  0.992171  0.285546
# b       NaN       NaN       NaN
# c  0.601204  0.072889  0.324261
# d -0.026268  1.287403  1.684323
# e       NaN       NaN       NaN
# f  0.845159 -0.238106  0.765342
#
# Nan-with True fill:
#
# a    False
# b     True
# c    False
# d    False
# e     True
# f    False
# Name: one, dtype: bool

# %%
df=pd.DataFrame(np.random.randn(4,3), index=['a','c','d','f'],
columns=['one','two','three'])
df = df.reindex(['a','b','c','d','e','f'])
print("Original Dataframe:\n",df)
print("\nNaN - Filled with Background values:\n")
print(df.fillna(method='bfill'))
# Out:
# Original Dataframe:
#          one       two     three
# a -0.024846  2.394763  1.328743
# b       NaN       NaN       NaN
# c -0.690634 -1.262180  0.824723
# d -1.922921  0.685358  0.638375
# e       NaN       NaN       NaN
# f  1.668554 -1.087063 -0.621695
#
# NaN - Filled with Background values:
#
#         one       two     three
# a -0.024846  2.394763  1.328743
# b -0.690634 -1.262180  0.824723
# c -0.690634 -1.262180  0.824723
# d -1.922921  0.685358  0.638375
# e  1.668554 -1.087063 -0.621695
# f  1.668554 -1.087063 -0.621695
# /tmp/ipykernel_16537/4216389697.py:6: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   print(df.fillna(method='bfill'))
