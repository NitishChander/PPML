# %% [markdown]
# <a href="https://colab.research.google.com/github/NitishChander/PPML/blob/main/Skill%20Test%205b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#5B
import pandas as pd
import matplotlib.pyplot as plt

# Create a dummy healthcare_data.csv file if it doesn't exist
try:
    with open("healthcare_data.csv", "x") as f:
        f.write("Age,Diagnosis\n30,Flu\n45,Cold\n22,Flu\n60,Diabetes\n35,Cold\n50,Flu\n28,Cold\n70,Diabetes\n40,Flu\n")
except FileExistsError:
    pass # File already exists, proceed

# 1. Load the dataset
df = pd.read_csv("healthcare_data.csv")

# Display column names and data types
print("Column Names and Data Types:\n")
print(df.dtypes)

# 2. Calculate average age of patients
average_age = df["Age"].mean()
print("\nAverage Age of Patients:", average_age)

# 3. Analyze diagnosis distribution
diagnosis_counts = df["Diagnosis"].value_counts()

print("\nDiagnosis Distribution:\n")
print(diagnosis_counts)

# Visualization of diagnosis distribution
plt.bar(diagnosis_counts.index, diagnosis_counts.values)
plt.title("Diagnosis Distribution")
plt.xlabel("Diagnosis")
plt.ylabel("Number of Patients")
plt.xticks(rotation=45)
plt.show()
# Out:
# Column Names and Data Types:
#
# Age           int64
# Diagnosis    object
# dtype: object
#
# Average Age of Patients: 42.22222222222222
#
# Diagnosis Distribution:
#
# Diagnosis
# Flu         4
# Cold        3
# Diabetes    2
# Name: count, dtype: int64
