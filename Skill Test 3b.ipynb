# %% [markdown]
# <a href="https://colab.research.google.com/github/NitishChander/PPML/blob/main/Skill%20Test%203b.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#3B
import numpy as np

# Stock A price data (5 days × 3 features: Open, High, Low)
stock_A = np.array([
[100, 105, 98],
[102, 108, 101],
[104, 110, 103],
[103, 107, 100],
[105, 112, 104]
])

# Stock B price data (5 days × 3 features: Open, High, Low)
stock_B = np.array([
[98, 103, 95],
[101, 106, 99],
[102, 109, 100],
[100, 104, 97],
[103, 108, 101]
])

print("Stock A Data:\n", stock_A)
print("\nStock B Data:\n", stock_B)

# Element-wise sum
sum_matrix = stock_A + stock_B

print("\nElement-wise Sum of Stock Prices:\n", sum_matrix)

# Element-wise difference
difference_matrix = stock_A - stock_B

print("\nElement-wise Difference of Stock Prices:\n", difference_matrix)
# Out:
# Stock A Data:
#  [[100 105  98]
#  [102 108 101]
#  [104 110 103]
#  [103 107 100]
#  [105 112 104]]
#
# Stock B Data:
#  [[ 98 103  95]
#  [101 106  99]
#  [102 109 100]
#  [100 104  97]
#  [103 108 101]]
#
# Element-wise Sum of Stock Prices:
#  [[198 208 193]
#  [203 214 200]
#  [206 219 203]
#  [203 211 197]
#  [208 220 205]]
#
# Element-wise Difference of Stock Prices:
#  [[2 2 3]
#  [1 2 2]
#  [2 1 3]
#  [3 3 3]
#  [2 4 3]]
